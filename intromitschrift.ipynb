# %% [markdown]
# # A simple plot Markdown field

# %%
import numpy as np

import matplotlib.pyplot as plt

# generate some sample data
data = np.random.randn(100)

plt.boxplot(data)
plt.title("Simple Boxplot of Random Data")
plt.show()

# %%
print("Hello!")

x = 3
if x > 5:
    print("x is greater than 5")
else:
    print("x is not greater than 5")

def sayhello(name):
    '''diese Funktion sagt Hallo zu jemandem'''
    print ("Hello" + name)

#hilfe erhalten: 
# siehe auch kaggle.com 
help(sayhello)
# Out:
# Hello!
# x is not greater than 5
# Help on function sayhello in module __main__:
#
# sayhello(name)
#     diese Funktion sagt Hallo zu jemandem

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# libraries:
import math
print(math.sqrt(16))
# oder
import math as mt 
print(mt.sqrt(16))
# Out:
# 4.0
# 4.0

# %%
import pandas as pd
# funktioniert nicht, muss man erst installieren: im Terminal:  pip install pandas

# benötigte pakete in ein textfile geben: requirements.txt
# numpy: funktionen, arrays, matritzen
# seaborrn: zum visualisieren von Daten (erweitert matplotlib)
# pandas: führt den Datentyp Dataframe ein (tabelle)
    # ein dataframe besteht aus series (spalten) und index (zeilen)
    # funktionen wie df.head() , 
    # df.iloc[0:5] (erste 5 zeilen), erste zeile von allen spalten: df.iloc[0,:]
# scikit-learn: sklearn enthält den iris datensatz 
import math as mt
import numpy as np
from sklearn import datasets # importiert nur datasets (nur ein Untermodul)

# %%
iris = datasets.load_iris() # lädt den iris datensatz in die variable iris
help(datasets.load_iris) # hilfe zu dieser funktion erhalten
# Out:
# Help on function load_iris in module sklearn.datasets._base:
#
# load_iris(*, return_X_y=False, as_frame=False)
#     Load and return the iris dataset (classification).
#
#     The iris dataset is a classic and very easy multi-class classification
#     dataset.
#
#     =================   ==============
#     Classes                          3
#     Samples per class               50
#     Samples total                  150
#     Dimensionality                   4
#     Features            real, positive
#     =================   ==============
#
#     Read more in the :ref:`User Guide <iris_dataset>`.
#
#     .. versionchanged:: 0.20
#         Fixed two wrong data points according to Fisher's paper.
#         The new version is the same as in R, but not as in the UCI
#         Machine Learning Repository.
#
#     Parameters
#     ----------
#     return_X_y : bool, default=False
#         If True, returns ``(data, target)`` instead of a Bunch object. See
# ...

# %%
# plot the iris dataset
plt.figure()
iris = iris_X
plt.scatter(iris['sepal length (cm)'], iris['sepal width (cm)'],
            c=iris['species'].astype('category').cat.codes)
plt.xlabel('sepal length')
plt.ylabel('sepal width')
plt.title('Iris sepal dimensions')
plt.show()
