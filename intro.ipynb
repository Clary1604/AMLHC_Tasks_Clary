# %% [markdown]
# # A simple plot Markdown datei

# %%
import numpy as np

import matplotlib.pyplot as plt

# generate some sample data
data = np.random.randn(100)

plt.boxplot(data)
plt.title("Simple Boxplot")
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.
