# %% [markdown]
# Supervized Learning - Classification

# %%
# import libraries
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
# use diabetes.csv dataset   

df = pd.read_csv("diabetes.csv")
df.head()
# Out:
#    preg  plas  pres  skin  insu  mass   pedi  age            class
# 0     6   148    72    35     0  33.6  0.627   50  tested_positive
# 1     1    85    66    29     0  26.6  0.351   31  tested_negative
# 2     8   183    64     0     0  23.3  0.672   32  tested_positive
# 3     1    89    66    23    94  28.1  0.167   21  tested_negative
# 4     0   137    40    35   168  43.1  2.288   33  tested_positive

# %%
# Fit a Generalized Linear Model (Logistic Regression)
# Use LogisticRegression from sklearn.linear_model
from sklearn.linear_model import LogisticRegression
model = LogisticRegression( max_iter=1000)  # Increase max_iter if convergence issues arise
# Fit the model using .fit(X, y)
X = df.drop("class", axis=1)
y = df["class"]
model.fit(X, y)
# Out:
# LogisticRegression(max_iter=1000)

# %%
# Evaluate the model
# Use .coef_ and .intercept_ to extract coefficients
print("Coefficients:", model.coef_)
print("Intercept:", model.intercept_)
# Use sklearn.metrics.accuracy_score() for model performance
from sklearn.metrics import accuracy_score
y_pred = model.predict(X)
accuracy = accuracy_score(y, y_pred)
print("Accuracy:", accuracy)

# Use matplotlib.pyplot.plot() to visualize residuals or performance doesn't make sense.
# Out:
# Coefficients: [[ 1.22516387e-01  3.51112470e-02 -1.32987686e-02  7.83076076e-04
#   -1.17400225e-03  8.96460243e-02  8.67924089e-01  1.49800088e-02]]
# Intercept: [-8.36507711]
# Accuracy: 0.78125
